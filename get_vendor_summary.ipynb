# %%
import sqlite3
import pandas as pd
import logging
from ingestion_db import ingest_db

from explorator_data_analysis import Vendor_sales_summary

logging.basicConfig(
    filename="logs/get_vendor_summary.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)


def create_vendor_summary(conn):
    Vendor_sales_summary = pd.read_sql("""
WITH FreightSummary AS (
    SELECT
        VendorNumber,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
), 
PurchaseSummary AS (
    SELECT
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Volume,
        pp.Price AS ActualPrice,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Volume, pp.Price
),
SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,                           
    ps.TotalPurchaseDollars, 
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC
""", conn)
    return Vendor_sales_summary

def clean_data(df):
    """this function help to clean the data"""
    #changing datatype to float
    df["Volume"] = df["Volume"].astype("float")

    #filling missing value with 0
    df.fillna(0, inplace=True)

    #removing spaces from categorical columns
    df["VendorName"] = df["VendorName"].str.strip()
    df["Description"] = df["Description"].str.strip()

    #Creating new column for better analysis
    df["GrossProfit"] = df["TotalSalesDollars"] - df["TotalPurchaseDollars"]
    df["ProfitMargin"] = df["GrossProfit"]/df["TotalSalesDollars"]
    df["StockTurnover"] = df["TotalSalesQuantity"]/df["TotalPurchaseQuantity"]
    df["SalestoPurchaseratio"] = df["TotalSalesDollars"]/df["TotalPurchaseDollars"]

    return df

if __name__ =="__main__":
    #creating database connection
    conn = sqlite3.connect("inventory.db")

    logging.info("creating vendor summary table......")
    summary_df = create_vendor_summary1(conn)
    logging.info(summary_df.head())

    logging.info("cleaning data....")
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())

    logging.info("investing data...")
    ingest_db(clean_df, "vendor_sales_summary1", conn)
    logging.info("complete")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 import logging
#       4 from ingestion_db import ingest_db
# ----> 6 from explorator_data_analysis import Vendor_sales_summary
#       8 logging.basicConfig(
#       9     filename="logs/get_vendor_summary.log",
#      10     level=logging.DEBUG,
#      11     format="%(asctime)s - %(levelname)s - %(message)s",
#      12     filemode="a"
#      13 )
#      16 def create_vendor_summary(conn):
#
# File ~\Downloads\Vendor\explorator_data_analysis.py:2964
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "8a9a00bf-f6f3-4886-a504-2c6115c64ff6",
#       6    "metadata": {},
#       7    "source": [
#       8     "# Exploratory Data Analysis\n",
#       9     " Understanding the datasets to explore how the data is present in the database and if there is a need for creating some aggregated tables that can help with\n",
#      10     "\n",
#      11     "\n",
#      12     "- Vendor Selection for profitability,\n",
#      13     "\n",
#      14     "\n",
#      15     "- Product Pricing Optimization"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 1,
#      21    "id": "64a76a73-2b79-412a-a9f1-f5ffc0340cad",
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "import pandas as pd\n",
#      26     "import sqlite3"
#      27    ]
#      28   },
#      29   {
#      30    "cell_type": "code",
#      31    "execution_count": 2,
#      32    "id": "37dbe2ce-6cb2-481c-9376-d93062fc6863",
#      33    "metadata": {},
#      34    "outputs": [],
#      35    "source": [
#      36     "#creating database connection\n",
#      37     "conn= sqlite3.connect('inventory.db')"
#      38    ]
#      39   },
#      40   {
#      41    "cell_type": "code",
#      42    "execution_count": 3,
#      43    "id": "7b83aa54-697b-4331-ac08-19674cadb9f4",
#      44    "metadata": {},
#      45    "outputs": [
#      46     {
#      47      "data": {
#      48       "text/html": [
#      49        "<div>\n",
#      50        "<style scoped>\n",
#      51        "    .dataframe tbody tr th:only-of-type {\n",
#      52        "        vertical-align: middle;\n",
#      53        "    }\n",
#      54        "\n",
#      55        "    .dataframe tbody tr th {\n",
#      56        "        vertical-align: top;\n",
#      57        "    }\n",
#      58        "\n",
#      59        "    .dataframe thead th {\n",
#      60        "        text-align: right;\n",
#      61        "    }\n",
#      62        "</style>\n",
#      63        "<table border=\"1\" class=\"dataframe\">\n",
#      64        "  <thead>\n",
#      65        "    <tr style=\"text-align: right;\">\n",
#      66        "      <th></th>\n",
#      67        "      <th>name</th>\n",
#      68        "    </tr>\n",
#      69        "  </thead>\n",
#      70        "  <tbody>\n",
#      71        "    <tr>\n",
#      72        "      <th>0</th>\n",
#      73        "      <td>begin_inventory</td>\n",
#      74        "    </tr>\n",
#      75        "    <tr>\n",
#      76        "      <th>1</th>\n",
#      77        "      <td>end_inventory</td>\n",
#      78        "    </tr>\n",
#      79        "    <tr>\n",
#      80        "      <th>2</th>\n",
#      81        "      <td>purchases</td>\n",
#      82        "    </tr>\n",
#      83        "    <tr>\n",
#      84        "      <th>3</th>\n",
#      85        "      <td>purchase_prices</td>\n",
#      86        "    </tr>\n",
#      87        "    <tr>\n",
#      88        "      <th>4</th>\n",
#      89        "      <td>sales</td>\n",
#      90        "    </tr>\n",
#      91        "    <tr>\n",
#      92        "      <th>5</th>\n",
#      93        "      <td>vendor_invoice</td>\n",
#      94        "    </tr>\n",
#      95        "  </tbody>\n",
#      96        "</table>\n",
#      97        "</div>"
#      98       ],
#      99       "text/plain": [
#     100        "              name\n",
#     101        "0  begin_inventory\n",
#     102        "1    end_inventory\n",
#     103        "2        purchases\n",
#     104        "3  purchase_prices\n",
#     105        "4            sales\n",
#     106        "5   vendor_invoice"
#     107       ]
#     108      },
#     109      "execution_count": 3,
#     110      "metadata": {},
#     111      "output_type": "execute_result"
#     112     }
#     113    ],
#     114    "source": [
#     115     "#checking tables present in the database\n",
#     116     "tables=pd.read_sql_query(\"SELECT name FROM sqlite_master WHERE type='table'\", conn)\n",
#     117     "tables                         "
#     118    ]
#     119   },
#     120   {
#     121    "cell_type": "code",
#     122    "execution_count": 4,
#     123    "id": "b0a002d5-bf83-497a-a82a-0d6868d00b6e",
#     124    "metadata": {},
#     125    "outputs": [
#     126     {
#     127      "data": {
#     128       "text/html": [
#     129        "<div>\n",
#     130        "<style scoped>\n",
#     131        "    .dataframe tbody tr th:only-of-type {\n",
#     132        "        vertical-align: middle;\n",
#     133        "    }\n",
#     134        "\n",
#     135        "    .dataframe tbody tr th {\n",
#     136        "        vertical-align: top;\n",
#     137        "    }\n",
#     138        "\n",
#     139        "    .dataframe thead th {\n",
#     140        "        text-align: right;\n",
#     141        "    }\n",
#     142        "</style>\n",
#     143        "<table border=\"1\" class=\"dataframe\">\n",
#     144        "  <thead>\n",
#     145        "    <tr style=\"text-align: right;\">\n",
#     146        "      <th></th>\n",
#     147        "      <th>count(*)</th>\n",
#     148        "    </tr>\n",
#     149        "  </thead>\n",
#     150        "  <tbody>\n",
#     151        "    <tr>\n",
#     152        "      <th>0</th>\n",
#     153        "      <td>2372474</td>\n",
#     154        "    </tr>\n",
#     155        "  </tbody>\n",
#     156        "</table>\n",
#     157        "</div>"
#     158       ],
#     159       "text/plain": [
#     160        "   count(*)\n",
#     161        "0   2372474"
#     162       ]
#     163      },
#     164      "execution_count": 4,
#     165      "metadata": {},
#     166      "output_type": "execute_result"
#     167     }
#     168    ],
#     169    "source": [
#     170     "# for table in tables['name']:\n",
#     171     "pd.read_sql(\"SELECT count(*) from purchases\",conn)\n",
#     172     "    # print('Count of records:',pd.read_sql(f\"SELECT count(*) as COUNT from {table}\",conn)['count'].values[0])"
#     173    ]
#     174   },
#     175   {
#     176    "cell_type": "code",
#     177    "execution_count": 5,
#     178    "id": "e8dc9f71-27a2-42df-875e-9ba7bb96308b",
#     179    "metadata": {},
#     180    "outputs": [
#     181     {
#     182      "name": "stdout",
#     183      "output_type": "stream",
#     184      "text": [
#     185       "-------------------------------------------------- begin_inventory --------------------------------------------------\n",
#     186       "Count of records: 206529\n",
#     187       "-------------------------------------------------- end_inventory --------------------------------------------------\n",
#     188       "Count of records: 224489\n",
#     189       "-------------------------------------------------- purchases --------------------------------------------------\n",
#     190       "Count of records: 2372474\n",
#     191       "-------------------------------------------------- purchase_prices --------------------------------------------------\n",
#     192       "Count of records: 12261\n",
#     193       "-------------------------------------------------- sales --------------------------------------------------\n",
#     194       "Count of records: 12825363\n",
#     195       "-------------------------------------------------- vendor_invoice --------------------------------------------------\n",
#     196       "Count of records: 5543\n"
#     197      ]
#     198     }
#     199    ],
#     200    "source": [
#     201     " for table in tables['name']:\n",
#     202     "    print('-'*50,f'{table}','-'*50)\n",
#     203     "    print('Count of records:',pd.read_sql(f\"SELECT count(*) as count from {table}\",conn)['count'].values[0])"
#     204    ]
#     205   },
#     206   {
#     207    "cell_type": "code",
#     208    "execution_count": 6,
#     209    "id": "ddb218f1-af30-4008-8374-f9e5c03360a3",
#     210    "metadata": {},
#     211    "outputs": [
#     212     {
#     213      "name": "stdout",
#     214      "output_type": "stream",
#     215      "text": [
#     216       "-------------------------------------------------- begin_inventory --------------------------------------------------\n",
#     217       "Count of records: 206529\n"
#     218      ]
#     219     },
#     220     {
#     221      "data": {
#     222       "text/html": [
#     223        "<div>\n",
#     224        "<style scoped>\n",
#     225        "    .dataframe tbody tr th:only-of-type {\n",
#     226        "        vertical-align: middle;\n",
#     227        "    }\n",
#     228        "\n",
#     229        "    .dataframe tbody tr th {\n",
#     230        "        vertical-align: top;\n",
#     231        "    }\n",
#     232        "\n",
#     233        "    .dataframe thead th {\n",
#     234        "        text-align: right;\n",
#     235        "    }\n",
#     236        "</style>\n",
#     237        "<table border=\"1\" class=\"dataframe\">\n",
#     238        "  <thead>\n",
#     239        "    <tr style=\"text-align: right;\">\n",
#     240        "      <th></th>\n",
#     241        "      <th>InventoryId</th>\n",
#     242        "      <th>Store</th>\n",
#     243        "      <th>City</th>\n",
#     244        "      <th>Brand</th>\n",
#     245        "      <th>Description</th>\n",
#     246        "      <th>Size</th>\n",
#     247        "      <th>onHand</th>\n",
#     248        "      <th>Price</th>\n",
#     249        "      <th>startDate</th>\n",
#     250        "    </tr>\n",
#     251        "  </thead>\n",
#     252        "  <tbody>\n",
#     253        "    <tr>\n",
#     254        "      <th>0</th>\n",
#     255        "      <td>1_HARDERSFIELD_58</td>\n",
#     256        "      <td>1</td>\n",
#     257        "      <td>HARDERSFIELD</td>\n",
#     258        "      <td>58</td>\n",
#     259        "      <td>Gekkeikan Black &amp; Gold Sake</td>\n",
#     260        "      <td>750mL</td>\n",
#     261        "      <td>8</td>\n",
#     262        "      <td>12.99</td>\n",
#     263        "      <td>2024-01-01</td>\n",
#     264        "    </tr>\n",
#     265        "    <tr>\n",
#     266        "      <th>1</th>\n",
#     267        "      <td>1_HARDERSFIELD_60</td>\n",
#     268        "      <td>1</td>\n",
#     269        "      <td>HARDERSFIELD</td>\n",
#     270        "      <td>60</td>\n",
#     271        "      <td>Canadian Club 1858 VAP</td>\n",
#     272        "      <td>750mL</td>\n",
#     273        "      <td>7</td>\n",
#     274        "      <td>10.99</td>\n",
#     275        "      <td>2024-01-01</td>\n",
#     276        "    </tr>\n",
#     277        "    <tr>\n",
#     278        "      <th>2</th>\n",
#     279        "      <td>1_HARDERSFIELD_62</td>\n",
#     280        "      <td>1</td>\n",
#     281        "      <td>HARDERSFIELD</td>\n",
#     282        "      <td>62</td>\n",
#     283        "      <td>Herradura Silver Tequila</td>\n",
#     284        "      <td>750mL</td>\n",
#     285        "      <td>6</td>\n",
#     286        "      <td>36.99</td>\n",
#     287        "      <td>2024-01-01</td>\n",
#     288        "    </tr>\n",
#     289        "    <tr>\n",
#     290        "      <th>3</th>\n",
#     291        "      <td>1_HARDERSFIELD_63</td>\n",
#     292        "      <td>1</td>\n",
#     293        "      <td>HARDERSFIELD</td>\n",
#     294        "      <td>63</td>\n",
#     295        "      <td>Herradura Reposado Tequila</td>\n",
#     296        "      <td>750mL</td>\n",
#     297        "      <td>3</td>\n",
#     298        "      <td>38.99</td>\n",
#     299        "      <td>2024-01-01</td>\n",
#     300        "    </tr>\n",
#     301        "    <tr>\n",
#     302        "      <th>4</th>\n",
#     303        "      <td>1_HARDERSFIELD_72</td>\n",
#     304        "      <td>1</td>\n",
#     305        "      <td>HARDERSFIELD</td>\n",
#     306        "      <td>72</td>\n",
#     307        "      <td>No. 3 London Dry Gin</td>\n",
#     308        "      <td>750mL</td>\n",
#     309        "      <td>6</td>\n",
#     310        "      <td>34.99</td>\n",
#     311        "      <td>2024-01-01</td>\n",
#     312        "    </tr>\n",
#     313        "  </tbody>\n",
#     314        "</table>\n",
#     315        "</div>"
#     316       ],
#     317       "text/plain": [
#     318        "         InventoryId  Store          City  Brand                  Description  \\\n",
#     319        "0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake   \n",
#     320        "1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP   \n",
#     321        "2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila   \n",
#     322        "3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila   \n",
#     323        "4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin   \n",
#     324        "\n",
#     325        "    Size  onHand  Price   startDate  \n",
#     326        "0  750mL       8  12.99  2024-01-01  \n",
#     327        "1  750mL       7  10.99  2024-01-01  \n",
#     328        "2  750mL       6  36.99  2024-01-01  \n",
#     329        "3  750mL       3  38.99  2024-01-01  \n",
#     330        "4  750mL       6  34.99  2024-01-01  "
#     331       ]
#     332      },
#     333      "metadata": {},
#     334      "output_type": "display_data"
#     335     },
#     336     {
#     337      "name": "stdout",
#     338      "output_type": "stream",
#     339      "text": [
#     340       "-------------------------------------------------- end_inventory --------------------------------------------------\n",
#     341       "Count of records: 224489\n"
#     342      ]
#     343     },
#     344     {
#     345      "data": {
#     346       "text/html": [
#     347        "<div>\n",
#     348        "<style scoped>\n",
#     349        "    .dataframe tbody tr th:only-of-type {\n",
#     350        "        vertical-align: middle;\n",
#     351        "    }\n",
#     352        "\n",
#     353        "    .dataframe tbody tr th {\n",
#     354        "        vertical-align: top;\n",
#     355        "    }\n",
#     356        "\n",
#     357        "    .dataframe thead th {\n",
#     358        "        text-align: right;\n",
#     359        "    }\n",
#     360        "</style>\n",
#     361        "<table border=\"1\" class=\"dataframe\">\n",
#     362        "  <thead>\n",
#     363        "    <tr style=\"text-align: right;\">\n",
#     364        "      <th></th>\n",
#     365        "      <th>InventoryId</th>\n",
#     366        "      <th>Store</th>\n",
#     367        "      <th>City</th>\n",
#     368        "      <th>Brand</th>\n",
#     369        "      <th>Description</th>\n",
#     370        "      <th>Size</th>\n",
#     371        "      <th>onHand</th>\n",
#     372        "      <th>Price</th>\n",
#     373        "      <th>endDate</th>\n",
#     374        "    </tr>\n",
#     375        "  </thead>\n",
#     376        "  <tbody>\n",
#     377        "    <tr>\n",
#     378        "      <th>0</th>\n",
#     379        "      <td>1_HARDERSFIELD_58</td>\n",
#     380        "      <td>1</td>\n",
#     381        "      <td>HARDERSFIELD</td>\n",
#     382        "      <td>58</td>\n",
#     383        "      <td>Gekkeikan Black &amp; Gold Sake</td>\n",
#     384        "      <td>750mL</td>\n",
#     385        "      <td>11</td>\n",
#     386        "      <td>12.99</td>\n",
#     387        "      <td>2024-12-31</td>\n",
#     388        "    </tr>\n",
#     389        "    <tr>\n",
#     390        "      <th>1</th>\n",
#     391        "      <td>1_HARDERSFIELD_62</td>\n",
#     392        "      <td>1</td>\n",
#     393        "      <td>HARDERSFIELD</td>\n",
#     394        "      <td>62</td>\n",
#     395        "      <td>Herradura Silver Tequila</td>\n",
#     396        "      <td>750mL</td>\n",
#     397        "      <td>7</td>\n",
#     398        "      <td>36.99</td>\n",
#     399        "      <td>2024-12-31</td>\n",
#     400        "    </tr>\n",
#     401        "    <tr>\n",
#     402        "      <th>2</th>\n",
#     403        "      <td>1_HARDERSFIELD_63</td>\n",
#     404        "      <td>1</td>\n",
#     405        "      <td>HARDERSFIELD</td>\n",
#     406        "      <td>63</td>\n",
#     407        "      <td>Herradura Reposado Tequila</td>\n",
#     408        "      <td>750mL</td>\n",
#     409        "      <td>7</td>\n",
#     410        "      <td>38.99</td>\n",
#     411        "      <td>2024-12-31</td>\n",
#     412        "    </tr>\n",
#     413        "    <tr>\n",
#     414        "      <th>3</th>\n",
#     415        "      <td>1_HARDERSFIELD_72</td>\n",
#     416        "      <td>1</td>\n",
#     417        "      <td>HARDERSFIELD</td>\n",
#     418        "      <td>72</td>\n",
#     419        "      <td>No. 3 London Dry Gin</td>\n",
#     420        "      <td>750mL</td>\n",
#     421        "      <td>4</td>\n",
#     422        "      <td>34.99</td>\n",
#     423        "      <td>2024-12-31</td>\n",
#     424        "    </tr>\n",
#     425        "    <tr>\n",
#     426        "      <th>4</th>\n",
#     427        "      <td>1_HARDERSFIELD_75</td>\n",
#     428        "      <td>1</td>\n",
#     429        "      <td>HARDERSFIELD</td>\n",
#     430        "      <td>75</td>\n",
#     431        "      <td>Three Olives Tomato Vodka</td>\n",
#     432        "      <td>750mL</td>\n",
#     433        "      <td>7</td>\n",
#     434        "      <td>14.99</td>\n",
#     435        "      <td>2024-12-31</td>\n",
#     436        "    </tr>\n",
#     437        "  </tbody>\n",
#     438        "</table>\n",
#     439        "</div>"
#     440       ],
#     441       "text/plain": [
#     442        "         InventoryId  Store          City  Brand                  Description  \\\n",
#     443        "0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake   \n",
#     444        "1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila   \n",
#     445        "2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila   \n",
#     446        "3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin   \n",
#     447        "4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka   \n",
#     448        "\n",
#     449        "    Size  onHand  Price     endDate  \n",
#     450        "0  750mL      11  12.99  2024-12-31  \n",
#     451        "1  750mL       7  36.99  2024-12-31  \n",
#     452        "2  750mL       7  38.99  2024-12-31  \n",
#     453        "3  750mL       4  34.99  2024-12-31  \n",
#     454        "4  750mL       7  14.99  2024-12-31  "
#     455       ]
#     456      },
#     457      "metadata": {},
#     458      "output_type": "display_data"
#     459     },
#     460     {
#     461      "name": "stdout",
#     462      "output_type": "stream",
#     463      "text": [
#     464       "-------------------------------------------------- purchases --------------------------------------------------\n",
#     465       "Count of records: 2372474\n"
#     466      ]
#     467     },
#     468     {
#     469      "data": {
#     470       "text/html": [
#     471        "<div>\n",
#     472        "<style scoped>\n",
#     473        "    .dataframe tbody tr th:only-of-type {\n",
#     474        "        vertical-align: middle;\n",
#     475        "    }\n",
#     476        "\n",
#     477        "    .dataframe tbody tr th {\n",
#     478        "        vertical-align: top;\n",
#     479        "    }\n",
#     480        "\n",
#     481        "    .dataframe thead th {\n",
#     482        "        text-align: right;\n",
#     483        "    }\n",
#     484        "</style>\n",
#     485        "<table border=\"1\" class=\"dataframe\">\n",
#     486        "  <thead>\n",
#     487        "    <tr style=\"text-align: right;\">\n",
#     488        "      <th></th>\n",
#     489        "      <th>InventoryId</th>\n",
#     490        "      <th>Store</th>\n",
#     491        "      <th>Brand</th>\n",
#     492        "      <th>Description</th>\n",
#     493        "      <th>Size</th>\n",
#     494        "      <th>VendorNumber</th>\n",
#     495        "      <th>VendorName</th>\n",
#     496        "      <th>PONumber</th>\n",
#     497        "      <th>PODate</th>\n",
#     498        "      <th>ReceivingDate</th>\n",
#     499        "      <th>InvoiceDate</th>\n",
#     500        "      <th>PayDate</th>\n",
#     501        "      <th>PurchasePrice</th>\n",
#     502        "      <th>Quantity</th>\n",
#     503        "      <th>Dollars</th>\n",
#     504        "      <th>Classification</th>\n",
#     505        "    </tr>\n",
#     506        "  </thead>\n",
#     507        "  <tbody>\n",
#     508        "    <tr>\n",
#     509        "      <th>0</th>\n",
#     510        "      <td>69_MOUNTMEND_8412</td>\n",
#     511        "      <td>69</td>\n",
#     512        "      <td>8412</td>\n",
#     513        "      <td>Tequila Ocho Plata Fresno</td>\n",
#     514        "      <td>750mL</td>\n",
#     515        "      <td>105</td>\n",
#     516        "      <td>ALTAMAR BRANDS LLC</td>\n",
#     517        "      <td>8124</td>\n",
#     518        "      <td>2023-12-21</td>\n",
#     519        "      <td>2024-01-02</td>\n",
#     520        "      <td>2024-01-04</td>\n",
#     521        "      <td>2024-02-16</td>\n",
#     522        "      <td>35.71</td>\n",
#     523        "      <td>6</td>\n",
#     524        "      <td>214.26</td>\n",
#     525        "      <td>1</td>\n",
#     526        "    </tr>\n",
#     527        "    <tr>\n",
#     528        "      <th>1</th>\n",
#     529        "      <td>30_CULCHETH_5255</td>\n",
#     530        "      <td>30</td>\n",
#     531        "      <td>5255</td>\n",
#     532        "      <td>TGI Fridays Ultimte Mudslide</td>\n",
#     533        "      <td>1.75L</td>\n",
#     534        "      <td>4466</td>\n",
#     535        "      <td>AMERICAN VINTAGE BEVERAGE</td>\n",
  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L   \n",
#     613        "4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL   \n",
#     614        "\n",
#     615        "   VendorNumber                   VendorName  PONumber      PODate  \\\n",
#     616        "0           105  ALTAMAR BRANDS LLC               8124  2023-12-21   \n",
#     617        "1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22   \n",
#     618        "2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22   \n",
#     619        "3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22   \n",
#     620        "4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24   \n",
#     621        "\n",
#     622        "  ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \\\n",
#     623        "0    2024-01-02  2024-01-04  2024-02-16          35.71         6   214.26   \n",
#     624        "1    2024-01-01  2024-01-07  2024-02-21           9.35         4    37.40   \n",
#     625        "2    2024-01-02  2024-01-07  2024-02-21           9.41         5    47.05   \n",
#     626        "3    2024-01-01  2024-01-07  2024-02-21           9.35         6    56.10   \n",
#     627        "4    2024-01-02  2024-01-09  2024-02-16          21.32         5   106.60   \n",
#     628        "\n",
#     629        "   Classification  \n",
#     630        "0               1  \n",
#     631        "1               1  \n",
#     632        "2               1  \n",
#     633        "3               1  \n",
#     634        "4               1  "
#     635       ]
#     636      },
#     637      "metadata": {},
#     638      "output_type": "display_data"
#     639     },
#     640     {
#     641      "name": "stdout",
#     642      "output_type": "stream",
#     643      "text": [
#     644       "-------------------------------------------------- purchase_prices --------------------------------------------------\n",
#     645       "Count of records: 12261\n"
#     646      ]
#     647     },
#     648     {
#     649      "data": {
#     650       "text/html": [
#     651        "<div>\n",
#     652        "<style scoped>\n",
#     653        "    .dataframe tbody tr th:only-of-type {\n",
#     654        "        vertical-align: middle;\n",
#     655        "    }\n",
#     656        "\n",
#     657        "    .dataframe tbody tr th {\n",
#     658        "        vertical-align: top;\n",
#     659        "    }\n",
#     660        "\n",
#     661        "    .dataframe thead th {\n",
#     662        "        text-align: right;\n",
#     663        "    }\n",
#     664        "</style>\n",
#     665        "<table border=\"1\" class=\"dataframe\">\n",
#     666        "  <thead>\n",
#     667        "    <tr style=\"text-align: right;\">\n",
#     668        "      <th></th>\n",
#     669        "      <th>Brand</th>\n",
#     670        "      <th>Description</th>\n",
#     671        "      <th>Price</th>\n",
#     672        "      <th>Size</th>\n",
#     673        "      <th>Volume</th>\n",
#     674        "      <th>Classification</th>\n",
#     675        "      <th>PurchasePrice</th>\n",
#     676        "      <th>VendorNumber</th>\n",
#     677        "      <th>VendorName</th>\n",
#     678        "    </tr>\n",
#     679        "  </thead>\n",
#     680        "  <tbody>\n",
#     681        "    <tr>\n",
#     682        "      <th>0</th>\n",
#     683        "      <td>58</td>\n",
#     684        "      <td>Gekkeikan Black &amp; Gold Sake</td>\n",
#     685        "      <td>12.99</td>\n",
#     686        "      <td>750mL</td>\n",
#     687        "      <td>750</td>\n",
#     688        "      <td>1</td>\n",
#     689        "      <td>9.28</td>\n",
#     690        "      <td>8320</td>\n",
#     691        "      <td>SHAW ROSS INT L IMP LTD</td>\n",
#     692        "    </tr>\n",
#     693        "    <tr>\n",
#     694        "      <th>1</th>\n",
#     695        "      <td>62</td>\n",
#     696        "      <td>Herradura Silver Tequila</td>\n",
#     697        "      <td>36.99</td>\n",
#     698        "      <td>750mL</td>\n",
#     699        "      <td>750</td>\n",
#     700        "      <td>1</td>\n",
#     701        "      <td>28.67</td>\n",
#     702        "      <td>1128</td>\n",
#     703        "      <td>BROWN-FORMAN CORP</td>\n",
#     704        "    </tr>\n",
#     705        "    <tr>\n",
#     706        "      <th>2</th>\n",
#     707        "      <td>63</td>\n",
#     708        "      <td>Herradura Reposado Tequila</td>\n",
#     709        "      <td>38.99</td>\n",
#     710        "      <td>750mL</td>\n",
#     711        "      <td>750</td>\n",
#     712        "      <td>1</td>\n",
#     713        "      <td>30.46</td>\n",
#     714        "      <td>1128</td>\n",
#     715        "      <td>BROWN-FORMAN CORP</td>\n",
#     716        "    </tr>\n",
#     717        "    <tr>\n",
#     718        "      <th>3</th>\n",
#     719        "      <td>72</td>\n",
#     720        "      <td>No. 3 London Dry Gin</td>\n",
#     721        "      <td>34.99</td>\n",
#     722        "      <td>750mL</td>\n",
#     723        "      <td>750</td>\n",
#     724        "      <td>1</td>\n",
#     725        "      <td>26.11</td>\n",
#     726        "      <td>9165</td>\n",
#     727        "      <td>ULTRA BEVERAGE COMPANY LLP</td>\n",
#     728        "    </tr>\n",
#     729        "    <tr>\n",
#     730        "      <th>4</th>\n",
#     731        "      <td>75</td>\n",
#     732        "      <td>Three Olives Tomato Vodka</td>\n",
#     733        "      <td>14.99</td>\n",
#     734        "      <td>750mL</td>\n",
#     735        "      <td>750</td>\n",
#     736        "      <td>1</td>\n",
#     737        "      <td>10.94</td>\n",
#     738        "      <td>7245</td>\n",
#     739        "      <td>PROXIMO SPIRITS INC.</td>\n",
#     740        "    </tr>\n",
#     741        "  </tbody>\n",
#     742        "</table>\n",
#     743        "</div>"
#     744       ],
#     745       "text/plain": [
#     746        "   Brand                  Description  Price   Size Volume  Classification  \\\n",
#     747        "0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1   \n",
#     748        "1     62     Herradura Silver Tequila  36.99  750mL    750               1   \n",
#     749        "2     63   Herradura Reposado Tequila  38.99  750mL    750               1   \n",
#     750        "3     72         No. 3 London Dry Gin  34.99  750mL    750               1   \n",
#     751        "4     75    Three Olives Tomato Vodka  14.99  750mL    750               1   \n",
#     752        "\n",
#     753        "   PurchasePrice  VendorNumber                   VendorName  \n",
#     754        "0           9.28          8320  SHAW ROSS INT L IMP LTD      \n",
#     755        "1          28.67          1128  BROWN-FORMAN CORP            \n",
#     756        "2          30.46          1128  BROWN-FORMAN CORP            \n",
#     757        "3          26.11          9165  ULTRA BEVERAGE COMPANY LLP   \n",
#     758        "4          10.94          7245  PROXIMO SPIRITS INC.         "
#     759       ]
#     760      },
#     761      "metadata": {},
#     762      "output_type": "display_data"
#     763     },
#     764     {
#     765      "name": "stdout",
#     766      "output_type": "stream",
#     767      "text": [
#     768       "-------------------------------------------------- sales --------------------------------------------------\n",
#     769       "Count of records: 12825363\n"
#     770      ]
#     771     },
#     772     {
#     773      "data": {
#     774       "text/html": [
#     775        "<div>\n",
#     776        "<style scoped>\n",
#     777        "    .dataframe tbody tr th:only-of-type {\n",
#     778        "        vertical-align: middle;\n",
#     779        "    }\n",
#     780        "\n",
#     781        "    .dataframe tbody tr th {\n",
#     782        "        vertical-align: top;\n",
#     783        "    }\n",
#     784        "\n",
#     785        "    .dataframe thead th {\n",
#     786        "        text-align: right;\n",
#     787        "    }\n",
#     788        "</style>\n",
#     789        "<table border=\"1\" class=\"dataframe\">\n",
#     790        "  <thead>\n",
#     791        "    <tr style=\"text-align: right;\">\n",
#     792        "      <th></th>\n",
#     793        "      <th>InventoryId</th>\n",
#     794        "      <th>Store</th>\n",
#     795        "      <th>Brand</th>\n",
#     796        "      <th>Description</th>\n",
#     797        "      <th>Size</th>\n",
#     798        "      <th>SalesQuantity</th>\n",
#     799        "      <th>SalesDollars</th>\n",
#     800        "      <th>SalesPrice</th>\n",
#     801        "      <th>SalesDate</th>\n",
#     802        "      <th>Volume</th>\n",
#     803        "      <th>Classification</th>\n",
#     804        "      <th>ExciseTax</th>\n",
#     805        "      <th>VendorNo</th>\n",
#     806        "      <th>VendorName</th>\n",
#     807        "    </tr>\n",
#     808        "  </thead>\n",
#     809        "  <tbody>\n",
#     810        "    <tr>\n",
#     811        "      <th>0</th>\n",
#     812        "      <td>1_HARDERSFIELD_1004</td>\n",
#     813        "      <td>1</td>\n",
#     814        "      <td>1004</td>\n",
#     815        "      <td>Jim Beam w/2 Rocks Glasses</td>\n",
#     816        "      <td>750mL</td>\n",
#     817        "      <td>1</td>\n",
#     818        "      <td>16.49</td>\n",
#     819        "      <td>16.49</td>\n",
#     820        "      <td>2024-01-01</td>\n",
#     821        "      <td>750.0</td>\n",
#     822        "      <td>1</td>\n",
#     823        "      <td>0.79</td>\n",
#     824        "      <td>12546</td>\n",
#     825        "      <td>JIM BEAM BRANDS COMPANY</td>\n",
#     826        "    </tr>\n",
#     827        "    <tr>\n",
#     828        "      <th>1</th>\n",
#     829        "      <td>1_HARDERSFIELD_1004</td>\n",
#     830        "      <td>1</td>\n",
#     831        "      <td>1004</td>\n",
#     832        "      <td>Jim Beam w/2 Rocks Glasses</td>\n",
#     833        "      <td>750mL</td>\n",
#     834        "      <td>2</td>\n",
#     835        "      <td>32.98</td>\n",
#     836        "      <td>16.49</td>\n",
#     837        "      <td>2024-01-02</td>\n",
#     838        "      <td>750.0</td>\n",
#     839        "      <td>1</td>\n",
#     840        "      <td>1.57</td>\n",
#     841        "      <td>12546</td>\n",
#     842        "      <td>JIM BEAM BRANDS COMPANY</td>\n",
#     843        "    </tr>\n",
#     844        "    <tr>\n",
#     845        "      <th>2</th>\n",
#     846        "      <td>1_HARDERSFIELD_1004</td>\n",
#     847        "      <td>1</td>\n",
#     848        "      <td>1004</td>\n",
#     849        "      <td>Jim Beam w/2 Rocks Glasses</td>\n",
#     850        "      <td>750mL</td>\n",
#     851        "      <td>1</td>\n",
#     852        "      <td>16.49</td>\n",
#     853        "      <td>16.49</td>\n",
#     854        "      <td>2024-01-03</td>\n",
#     855        "      <td>750.0</td>\n",
#     856        "      <td>1</td>\n",
#     857        "      <td>0.79</td>\n",
#     858        "      <td>12546</td>\n",
#     859        "      <td>JIM BEAM BRANDS COMPANY</td>\n",
#     860        "    </tr>\n",
#     861        "    <tr>\n",
#     862        "      <th>3</th>\n",
#     863        "      <td>1_HARDERSFIELD_1004</td>\n",
#     864        "      <td>1</td>\n",
#     865        "      <td>1004</td>\n",
#     866        "      <td>Jim Beam w/2 Rocks Glasses</td>\n",
#     867        "      <td>750mL</td>\n",
#     868        "      <td>1</td>\n",
#     869        "      <td>14.49</td>\n",
#     870        "      <td>14.49</td>\n",
#     871        "      <td>2024-01-08</td>\n",
#     872        "      <td>750.0</td>\n",
#     873        "      <td>1</td>\n",
#     874        "      <td>0.79</td>\n",
#     875        "      <td>12546</td>\n",
#     876        "      <td>JIM BEAM BRANDS COMPANY</td>\n",
#     877        "    </tr>\n",
#     878        "    <tr>\n",
#     879        "      <th>4</th>\n",
#     880        "      <td>1_HARDERSFIELD_1005</td>\n",
#     881        "      <td>1</td>\n",
#     882        "      <td>1005</td>\n",
#     883        "      <td>Maker's Mark Combo Pack</td>\n",
#     884        "      <td>375mL 2 Pk</td>\n",
#     885        "      <td>2</td>\n",
#     886        "      <td>69.98</td>\n",
#     887        "      <td>34.99</td>\n",
#     888        "      <td>2024-01-09</td>\n",
#     889        "      <td>375.0</td>\n",
#     890        "      <td>1</td>\n",
#     891        "      <td>0.79</td>\n",
#     892        "      <td>12546</td>\n",
#     893        "      <td>JIM BEAM BRANDS COMPANY</td>\n",
#     894        "    </tr>\n",
#     895        "  </tbody>\n",
#     896        "</table>\n",
#     897        "</div>"
#     898       ],
#     899       "text/plain": [
#     900        "           InventoryId  Store  Brand                 Description        Size  \\\n",
#     901        "0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL   \n",
#     902        "1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL   \n",
#     903        "2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL   \n",
#     904        "3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL   \n",
#     905        "4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk   \n",
#     906        "\n",
#     907        "   SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \\\n",
#     908        "0              1         16.49       16.49  2024-01-01   750.0   \n",
#     909        "1              2         32.98       16.49  2024-01-02   750.0   \n",
#     910        "2              1         16.49       16.49  2024-01-03   750.0   \n",
#     911        "3              1         14.49       14.49  2024-01-08   750.0   \n",
#     912        "4              2         69.98       34.99  2024-01-09   375.0   \n",
#     913        "\n",
#     914        "   Classification  ExciseTax  VendorNo                   VendorName  \n",
#     915        "0               1       0.79     12546  JIM BEAM BRANDS COMPANY      \n",
#     916        "1               1       1.57     12546  JIM BEAM BRANDS COMPANY      \n",
#     917        "2               1       0.79     12546  JIM BEAM BRANDS COMPANY      \n",
#     918        "3               1       0.79     12546  JIM BEAM BRANDS COMPANY      \n",
#     919        "4               1       0.79     12546  JIM BEAM BRANDS COMPANY      "
#     920       ]
#     921      },
#     922      "metadata": {},
#     923      "output_type": "display_data"
#     924     },
#     925     {
#     926      "name": "stdout",
#     927      "output_type": "stream",
#     928      "text": [
#     929       "-------------------------------------------------- vendor_invoice --------------------------------------------------\n",
#     930       "Count of records: 5543\n"
#     931      ]
#     932     },
#     933     {
#     934      "data": {
#     935       "text/html": [
#     936        "<div>\n",
#     937        "<style scoped>\n",
#     938        "    .dataframe tbody tr th:only-of-type {\n",
#     939        "        vertical-align: middle;\n",
#     940        "    }\n",
#     941        "\n",
#     942        "    .dataframe tbody tr th {\n",
#     943        "        vertical-align: top;\n",
#     944        "    }\n",
#     945        "\n",
#     946        "    .dataframe thead th {\n",
#     947        "        text-align: right;\n",
#     948        "    }\n",
#     949        "</style>\n",
#     950        "<table border=\"1\" class=\"dataframe\">\n",
#     951        "  <thead>\n",
#     952        "    <tr style=\"text-align: right;\">\n",
#     953        "      <th></th>\n",
#     954        "      <th>VendorNumber</th>\n",
#     955        "      <th>VendorName</th>\n",
#     956        "      <th>InvoiceDate</th>\n",
#     957        "      <th>PONumber</th>\n",
#     958        "      <th>PODate</th>\n",
#     959        "      <th>PayDate</th>\n",
#     960        "      <th>Quantity</th>\n",
#     961        "      <th>Dollars</th>\n",
#     962        "      <th>Freight</th>\n",
#     963        "      <th>Approval</th>\n",
#     964        "    </tr>\n",
#     965        "  </thead>\n",
#     966        "  <tbody>\n",
#     967        "    <tr>\n",
#     968        "      <th>0</th>\n",
#     969        "      <td>105</td>\n",
#     970        "      <td>ALTAMAR BRANDS LLC</td>\n",
#     971        "      <td>2024-01-04</td>\n",
#     972        "      <td>8124</td>\n",
#     973        "      <td>2023-12-21</td>\n",
#     974        "      <td>2024-02-16</td>\n",
#     975        "      <td>6</td>\n",
#     976        "      <td>214.26</td>\n",
#     977        "      <td>3.47</td>\n",
#     978        "      <td>None</td>\n",
#     979        "    </tr>\n",
#     980        "    <tr>\n",
#     981        "      <th>1</th>\n",
#     982        "      <td>4466</td>\n",
#     983        "      <td>AMERICAN VINTAGE BEVERAGE</td>\n",
#     984        "      <td>2024-01-07</td>\n",
#     985        "      <td>8137</td>\n",
#     986        "      <td>2023-12-22</td>\n",
#     987        "      <td>2024-02-21</td>\n",
#     988        "      <td>15</td>\n",
#     989        "      <td>140.55</td>\n",
#     990        "      <td>8.57</td>\n",
#     991        "      <td>None</td>\n",
#     992        "    </tr>\n",
#     993        "    <tr>\n",
#     994        "      <th>2</th>\n",
#     995        "      <td>388</td>\n",
#     996        "      <td>ATLANTIC IMPORTING COMPANY</td>\n",
#     997        "      <td>2024-01-09</td>\n",
#     998        "      <td>8169</td>\n",
#     999        "      <td>2023-12-24</td>\n",
#    1000        "      <td>2024-02-16</td>\n",
#    1001        "      <td>5</td>\n",
#    1002        "      <td>106.60</td>\n",
#    1003        "      <td>4.61</td>\n",
#    1004        "      <td>None</td>\n",
#    1005        "    </tr>\n",
#    1006        "    <tr>\n",
#    1007        "      <th>3</th>\n",
#    1008        "      <td>480</td>\n",
#    1009        "      <td>BACARDI USA INC</td>\n",
#    1010        "      <td>2024-01-12</td>\n",
#    1011        "      <td>8106</td>\n",
#    1012        "      <td>2023-12-20</td>\n",
#    1013        "      <td>2024-02-05</td>\n",
#    1014        "      <td>10100</td>\n",
#    1015        "      <td>137483.78</td>\n",
#    1016        "      <td>2935.20</td>\n",
#    1017        "      <td>None</td>\n",
#    1018        "    </tr>\n",
#    1019        "    <tr>\n",
#    1020        "      <th>4</th>\n",
#    1021        "      <td>516</td>\n",
#    1022        "      <td>BANFI PRODUCTS CORP</td>\n",
#    1023        "      <td>2024-01-07</td>\n",
#    1024        "      <td>8170</td>\n",
#    1025        "      <td>2023-12-24</td>\n",
#    1026        "      <td>2024-02-12</td>\n",
#    1027        "      <td>1935</td>\n",
#    1028        "      <td>15527.25</td>\n",
#    1029        "      <td>429.20</td>\n",
#    1030        "      <td>None</td>\n",
#    1031        "    </tr>\n",
#    1032        "  </tbody>\n",
#    1033        "</table>\n",
#    1034        "</div>"
#    1035       ],
#    1036       "text/plain": [
#    1037        "   VendorNumber                   VendorName InvoiceDate  PONumber  \\\n",
#    1038        "0           105  ALTAMAR BRANDS LLC           2024-01-04      8124   \n",
#    1039        "1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137   \n",
#    1040        "2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169   \n",
#    1041        "3           480  BACARDI USA INC              2024-01-12      8106   \n",
#    1042        "4           516  BANFI PRODUCTS CORP          2024-01-07      8170   \n",
#    1043        "\n",
#    1044        "       PODate     PayDate  Quantity    Dollars  Freight Approval  \n",
#    1045        "0  2023-12-21  2024-02-16         6     214.26     3.47     None  \n",
#    1046        "1  2023-12-22  2024-02-21        15     140.55     8.57     None  \n",
#    1047        "2  2023-12-24  2024-02-16         5     106.60     4.61     None  \n",
#    1048        "3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None  \n",
#    1049        "4  2023-12-24  2024-02-12      1935   15527.25   429.20     None  "
#    1050       ]
#    1051      },
#    1052      "metadata": {},
#    1053      "output_type": "display_data"
#    1054     }
#    1055    ],
#    1056    "source": [
#    1057     " for table in tables['name']:\n",
#    1058     "    print('-'*50,f'{table}','-'*50)\n",
#    1059     "    print('Count of records:',pd.read_sql(f\"SELECT count(*) as count from {table}\",conn)['count'].values[0])\n",
#    1060     "    display(pd.read_sql(f\"SELECT * from {table} limit 5\",conn))"
#    1061    ]
#    1062   },
#    1063   {
#    1064    "cell_type": "code",
#    1065    "execution_count": 7,
#    1066    "id": "0cbd14f7-d2d0-4caa-87e1-41869644adf6",
#    1067    "metadata": {},
#    1068    "outputs": [
#    1069     {
#    1070      "data": {
#    1071       "text/html": [
#    1072        "<div>\n",
#    1073        "<style scoped>\n",
#    1074        "    .dataframe tbody tr th:only-of-type {\n",
#    1075        "        vertical-align: middle;\n",
#    1076        "    }\n",
#    1077        "\n",
#    1078        "    .dataframe tbody tr th {\n",
#    1079        "        vertical-align: top;\n",
#    1080        "    }\n",
#    1081        "\n",
#    1082        "    .dataframe thead th {\n",
#    1083        "        text-align: right;\n",
#    1084        "    }\n",
#    1085        "</style>\n",
#    1086        "<table border=\"1\" class=\"dataframe\">\n",
#    1087        "  <thead>\n",
#    1088        "    <tr style=\"text-align: right;\">\n",
#    1089        "      <th></th>\n",
#    1090        "      <th>InventoryId</th>\n",
#    1091        "      <th>Store</th>\n",
#    1092        "      <th>Brand</th>\n",
#    1093        "      <th>Description</th>\n",
#    1094        "      <th>Size</th>\n",
#    5697        "      <td>4.46</td>\n",
#    5698        "      <td>38994.78</td>\n",
#    5699        "      <td>84.43</td>\n",
#    5700        "      <td>99.166079</td>\n",
#    5701        "      <td>99.166079</td>\n",
#    5702        "      <td>86.000000</td>\n",
#    5703        "      <td>119.915493</td>\n",
#    5704        "    </tr>\n",
#    5705        "  </tbody>\n",
#    5706        "</table>\n",
#    5707        "<p>10692 rows × 19 columns</p>\n",
#    5708        "</div>"
#    5709       ],
#    5710       "text/plain": [
#    5711        "       VendorNumber                VendorName  Brand  \\\n",
#    5712        "0              1128         BROWN-FORMAN CORP   1233   \n",
#    5713        "1              4425     MARTIGNETTI COMPANIES   3405   \n",
#    5714        "2             17035         PERNOD RICARD USA   8068   \n",
#    5715        "3              3960  DIAGEO NORTH AMERICA INC   4261   \n",
#    5716        "4              3960  DIAGEO NORTH AMERICA INC   3545   \n",
#    5717        "...             ...                       ...    ...   \n",
#    5718        "10687          9815            WINE GROUP INC   8527   \n",
#    5719        "10688          8004            SAZERAC CO INC   5683   \n",
#    5720        "10689          3924  HEAVEN HILL DISTILLERIES   9123   \n",
#    5721        "10690          3960  DIAGEO NORTH AMERICA INC   6127   \n",
#    5722        "10691          7245      PROXIMO SPIRITS INC.   3065   \n",
#    5723        "\n",
#    5724        "                       Description  PurchasePrice  ActualPrice  Volume  \\\n",
#    5725        "0          Jack Daniels No 7 Black          26.27        36.99  1750.0   \n",
#    5726        "1            Tito's Handmade Vodka          23.19        28.99  1750.0   \n",
#    5727        "2                 Absolut 80 Proof          18.24        24.99  1750.0   \n",
#    5728        "3           Capt Morgan Spiced Rum          16.17        22.99  1750.0   \n",
#    5729        "4                  Ketel One Vodka          21.89        29.99  1750.0   \n",
#    5730        "...                            ...            ...          ...     ...   \n",
#    5731        "10687  Concannon Glen Ellen Wh Zin           1.32         4.99   750.0   \n",
#    5732        "10688  Dr McGillicuddy's Apple Pie           0.39         0.49    50.0   \n",
#    5733        "10689              Deep Eddy Vodka           0.74         0.99    50.0   \n",
#    5734        "10690  The Club Strawbry Margarita           1.47         1.99   200.0   \n",
#    5735        "10691     Three Olives Grape Vodka           0.71         0.99    50.0   \n",
#    5736        "\n",
#    5737        "       TotalPurchaseQuantity  TotalPurchaseDollars  TotalSalesQuantity  \\\n",
#    5738        "0                     145080            3811251.60            142049.0   \n",
#    5739        "1                     164038            3804041.22            160247.0   \n",
#    5740        "2                     187407            3418303.68            187140.0   \n",
#    5741        "3                     201682            3261197.94            200412.0   \n",
#    5742        "4                     138109            3023206.01            135838.0   \n",
#    5743        "...                      ...                   ...                 ...   \n",
#    5744        "10687                      2                  2.64                 5.0   \n",
#    5745        "10688                      6                  2.34               134.0   \n",
#    5746        "10689                      2                  1.48                 2.0   \n",
#    5747        "10690                      1                  1.47                72.0   \n",
#    5748        "10691                      1                  0.71                86.0   \n",
#    5749        "\n",
#    5750        "       TotalSalesDollars  TotalSalesPrice  TotalExciseTax  FreightCost  \\\n",
#    5751        "0             5101919.51        672819.31       260999.20     68601.68   \n",
#    5752        "1             4819073.49        561512.37       294438.66    144929.24   \n",
#    5753        "2             4538120.60        461140.15       343854.07    123780.22   \n",
#    5754        "3             4475972.88        420050.01       368242.80    257032.07   \n",
#    5755        "4             4223107.62        545778.28       249587.83    257032.07   \n",
#    5756        "...                  ...              ...             ...          ...   \n",
#    5757        "10687              15.95            10.96            0.55     27100.41   \n",
#    5758        "10688              65.66             1.47            7.04     50293.62   \n",
#    5759        "10689               1.98             0.99            0.10     14069.87   \n",
#    5760        "10690             143.28            77.61           15.12    257032.07   \n",
#    5761        "10691              85.14            33.66            4.46     38994.78   \n",
#    5762        "\n",
#    5763        "       GrossProfit  ProftMargin  ProfitMargin  StockTurnover  \\\n",
#    5764        "0       1290667.91    25.297693     25.297693       0.979108   \n",
#    5765        "1       1015032.27    21.062810     21.062810       0.976890   \n",
#    5766        "2       1119816.92    24.675786     24.675786       0.998575   \n",
#    5767        "3       1214774.94    27.139908     27.139908       0.993703   \n",
#    5768        "4       1199901.61    28.412764     28.412764       0.983556   \n",
#    5769        "...            ...          ...           ...            ...   \n",
#    5770        "10687        13.31    83.448276     83.448276       2.500000   \n",
#    5771        "10688        63.32    96.436186     96.436186      22.333333   \n",
#    5772        "10689         0.50    25.252525     25.252525       1.000000   \n",
#    5773        "10690       141.81    98.974037     98.974037      72.000000   \n",
#    5774        "10691        84.43    99.166079     99.166079      86.000000   \n",
#    5775        "\n",
#    5776        "       SalestoPurchaseRatio  \n",
#    5777        "0                  1.338647  \n",
#    5778        "1                  1.266830  \n",
#    5779        "2                  1.327594  \n",
#    5780        "3                  1.372493  \n",
#    5781        "4                  1.396897  \n",
#    5782        "...                     ...  \n",
#    5783        "10687              6.041667  \n",
#    5784        "10688             28.059829  \n",
#    5785        "10689              1.337838  \n",
#    5786        "10690             97.469388  \n",
#    5787        "10691            119.915493  \n",
#    5788        "\n",
#    5789        "[10692 rows x 19 columns]"
#    5790       ]
#    5791      },
#    5792      "execution_count": 70,
#    5793      "metadata": {},
#    5794      "output_type": "execute_result"
#    5795     }
#    5796    ],
#    5797    "source": [
#    5798     "pd.read_sql_query(\"Select * from vendor_sales_summary\",conn)"
#    5799    ]
#    5800   },
#    5801   {
#    5802    "cell_type": "code",
#    5803    "execution_count": null,
#    5804    "id": "c1a58fb1-9160-4f94-b88f-d5956a4b7ad3",
#    5805    "metadata": {},
#    5806    "outputs": [],
#    5807    "source": []
#    5808   }
#    5809  ],
#    5810  "metadata": {
#    5811   "kernelspec": {
#    5812    "display_name": "Python [conda env:base] *",
#    5813    "language": "python",
#    5814    "name": "conda-base-py"
#    5815   },
#    5816   "language_info": {
#    5817    "codemirror_mode": {
#    5818     "name": "ipython",
#    5819     "version": 3
#    5820    },
#    5821    "file_extension": ".py",
#    5822    "mimetype": "text/x-python",
#    5823    "name": "python",
#    5824    "nbconvert_exporter": "python",
#    5825    "pygments_lexer": "ipython3",
#    5826    "version": "3.12.7"
#    5827   }
#    5828  },
#    5829  "nbformat": 4,
#    5830  "nbformat_minor": 5
#    5831 }
#
# NameError: name 'null' is not defined
